# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjal272/HDSC22/blob/main/Stage_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')
df
# Out:
#        Area Code      Area  Item Code  ...     Y2016     Y2017     Y2018
# 0              4   Algeria       2501  ...  40551.00  41389.00  42228.00
# 1              4   Algeria       2501  ...      0.00      0.00      0.00
# 2              4   Algeria       2901  ...   3372.00   3341.00   3322.00
# 3              4   Algeria       2901  ...     94.72     92.82     91.83
# 4              4   Algeria       2901  ...     77.40     80.19     77.28
# ...          ...       ...        ...  ...       ...       ...       ...
# 60938        181  Zimbabwe       2899  ...     33.00     19.00     16.00
# 60939        181  Zimbabwe       2899  ...      2.35      1.33      1.08
# 60940        181  Zimbabwe       2899  ...      3.00      1.00      1.00
# 60941        181  Zimbabwe       2899  ...      0.08      0.04      0.04
# 60942        181  Zimbabwe       2899  ...      0.03      0.02      0.01
#
# [60943 rows x 12 columns]

# %% [markdown]
# Total sum of Animal Fat produced in 2014 and 2017 respectively: 209460.54 and 269617.53

# %%
df.groupby('Item')['Y2014','Y2017'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %% [markdown]
# Mean and Standard deviation for the year 2015 to 3 decimal places is 135.236 and 1603.404 respectively.

# %%
df['Y2015'].describe().round(3)
# Out:
# count     59395.000
# mean        135.236
# std        1603.404
# min       -3161.000
# 25%           0.000
# 50%           0.080
# 75%           8.460
# max      181137.000
# Name: Y2015, dtype: float64

# %% [markdown]
# Total number of missing data in 2016

# %%
df['Y2016'].isnull().sum()
# Out:
# 1535

# %% [markdown]
# Percentage of missing data in 2016 to 2 decimal places

# %%
df['Y2016'].isnull().mean().round(4)*100
# Out:
# 2.52

# %% [markdown]
# Correlation

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code  ...     Y2016     Y2017     Y2018
# Area Code      1.000000  -0.005159     -0.000209  ...  0.005247  0.005006  0.005665
# Item Code     -0.005159   1.000000     -0.024683  ...  0.020109  0.021494  0.021314
# Element Code  -0.000209  -0.024683      1.000000  ...  0.023444  0.024254  0.024279
# Y2014          0.006164   0.021722      0.024457  ...  0.996081  0.995230  0.994872
# Y2015          0.005472   0.020857      0.023889  ...  0.995739  0.988048  0.988208
# Y2016          0.005247   0.020109      0.023444  ...  1.000000  0.992785  0.992757
# Y2017          0.005006   0.021494      0.024254  ...  0.992785  1.000000  0.998103
# Y2018          0.005665   0.021314      0.024279  ...  0.992757  0.998103  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# Year with the highest sum of Import Quantity : 2017
#
# Total number of the sum of Production in 2014 : 1931287.75

# %%
df.groupby(['Element'])['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                              Y2014  ...       Y2018
# Element                                             ...
# Domestic supply quantity                1996716.35  ...  2161192.10
# Export Quantity                          150020.64  ...   181594.80
# Fat supply quantity (g/capita/day)        10225.56  ...    10258.69
# Feed                                     216927.89  ...   233489.68
# Food                                    1212332.49  ...  1303841.28
# Food supply (kcal/capita/day)            454257.00  ...   455261.00
# Food supply quantity (kg/capita/yr)       49650.63  ...    49056.85
# Import Quantity                          274144.48  ...   287997.09
# ...

# %% [markdown]
# Element which had the highest sum in 2018: Domestic supply quantity
#
# Element which had the 3rd lowest sum in 2018: Protein supply quantity (g/capita/day)

# %%
df.groupby(['Element']).sum()['Y2018'].sort_values(ascending=False)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Production                                2075072.89
# Food                                      1303841.28
# Total Population - Both sexes             1140605.00
# Food supply (kcal/capita/day)              455261.00
# Processing                                 308429.00
# Import Quantity                            287997.09
# Feed                                       233489.68
# Export Quantity                            181594.80
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Food supply quantity (kg/capita/yr)         49056.85
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Protein supply quantity (g/capita/day)      11833.56
# Fat supply quantity (g/capita/day)          10258.69
# Tourist consumption                            90.00
# ...

# %% [markdown]
# Total Import Quantity in Algeria in 2018: 36238.29

# %%
pd.set_option('display.max_rows', None)
df.groupby(['Area','Element'])['Y2018'].sum()
# Out:
# Area                         Element
# Algeria                      Domestic supply quantity                   90023.42
#                              Export Quantity                              811.54
#                              Fat supply quantity (g/capita/day)           309.09
#                              Feed                                       10668.00
#                              Food                                       63736.33
#                              Food supply (kcal/capita/day)              13288.00
#                              Food supply quantity (kg/capita/yr)         1509.28
#                              Import Quantity                            36238.29
#                              Losses                                      7708.00
#                              Other uses (non-food)                       3970.08
#                              Processing                                  2479.00
# ...

# %% [markdown]
#  Total number of unique countries in the dataset

# %%
df['Area'].nunique()
# Out:
# 49
